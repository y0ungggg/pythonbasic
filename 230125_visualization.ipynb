# %%
import matplotlib as mpl
import matplotlib.pyplot as plt

# %%
# 주피터 내부에 그림을 표시하도록 함
# %matplotlib inline

# %%
plt.title('Plot')
plt.plot([1,4,9,16])
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %% [raw]
# 폰트를 설치하는 방법
# 1. 폰트를 다운로드 받습니다.
# - 무료 폰트 사이트 : http://noonnu.cc
# 2. 다운로드 받은 폰트를 실행하면 설치할 수 있습니다.
#
# 리눅스에서 네이버에서 제공하는 나눔 글꼴 설치하기는 방법입니다. 해당 방법은 Colab에서도 사용가능합니다.

# %%
import matplotlib.font_manager
font_list = matplotlib.font_manager.findSystemFonts()
font_list
# Out:
# ['/System/Library/Fonts/Supplemental/NotoSansSharada-Regular.ttf',
#  '/System/Library/Fonts/Supplemental/NotoSansOldPermic-Regular.ttf',
#  '/System/Library/Fonts/Supplemental/NotoSansSaurashtra-Regular.ttf',
#  '/System/Library/Fonts/ヒラギノ角ゴシック W6.ttc',
#  '/System/Library/Fonts/Keyboard.ttf',
#  '/System/Library/Fonts/Supplemental/STIXIntUpBol.otf',
#  '/System/Library/Fonts/Supplemental/Didot.ttc',
#  '/System/Library/Fonts/Supplemental/Times New Roman Bold.ttf',
#  '/System/Library/Fonts/Supplemental/Lao Sangam MN.ttf',
#  '/System/Library/Fonts/Supplemental/NotoSansEgyptianHieroglyphs-Regular.ttf',
#  '/System/Library/Fonts/Supplemental/NotoSansOldHungarian-Regular.ttf',
#  '/System/Library/Fonts/ヒラギノ角ゴシック W9.ttc',
#  '/System/Library/Fonts/Supplemental/NotoSansCham-Regular.ttf',
#  '/System/Library/Fonts/Supplemental/NotoSansBuginese-Regular.ttf',
#  '/System/Library/Fonts/Supplemental/Times New Roman Italic.ttf',
# ...

# %% [raw]
# mpl.rc('font',family='폰트명')
# mpl.rcParams['font.family']='폰트명'

# %%
import matplotlib.font_manager
font_list = matplotlib.font_manager.findSystemFonts(fontpaths=None, fontext='ttf')
[matplotlib.font_manager.FontProperties(fname=font).get_name() for font in font_list if 'Nanum' in font]
# Out:
# ['NanumGothic']

# %%
mpl.rcParams['font.family']='Malgun Gothic'

# %%
mpl.rcParams['font.family'] ='AppleGothic'

# %%
plt.title('한글제목')
plt.plot([1,2,3,4,5])
plt.show()

# %%
mpl.rcParams['axes.unicode_minus'] = False

# %%
global_font = {'family' : 'AppleGothic', 'size' :12, 'weight' : 'bold' }
mpl.rc('font', **global_font)

# %%
plt.title('한글제목')
plt.plot([10,20,30,40],[1,4,9,16])
plt.xlabel('엑스축 레이블')
plt.ylabel('와이축 레이블')
plt.show()

# %%
# 유니코드에서 음수 부호 설정
mpl.rc('axes',unicode_minus = False)

# %%
plt.title('rs-- 스타일의 plot')
plt.plot([10,20,30,40],[1,4,9,16], 'rp:')
plt.show()

# %% [raw]
# 스타일 문자열은 색상(color), 마커(maker), 선 종류(line style)의 순서로 지정한다. 만약 이 중 일부가 생략되면 디폴트값이 적용된다.

# %%
plt.title('스타일 적용 예')
plt.plot([10,20,30,40],[1,4,9,16], c='b', lw=5, ls='--', marker='o', ms=15, mec='g', mew=5, mfc='r')
plt.show()

# %%
plt.title('x,y축 범위 설정')
plt.plot([10,20,30,40],[1,4,9,16], c='b', lw=5, ls='--', marker='o', ms=15, mec='g', mew=5, mfc='r')
plt.xlim(0,50)
plt.ylim(-10,30)
plt.show()

# %%
import numpy as np
X = np.linspace(-np.pi, np.pi, 256)
C = np.cos(X)
plt.title('x축과 y축의 tick label 설정')
plt.plot(X,C)
plt.xticks([-np.pi, -np.pi/2, 0, np.pi/2, np.pi])
plt.yticks([-1,0,1])
plt.show()

# %%
X = np.linspace(-np.pi, np.pi, 256)
C = np.cos(X)
plt.title('TeX, 문자열로 tick label 설정')
plt.plot(X,C)
plt.xticks([-np.pi, -np.pi/2, 0, np.pi/2, np.pi],
          [r'$-\pi$', r'$-\pi/2$',r'$0$', r'$+\pi/2$', r'$+\pi$'])
plt.yticks([-1,0,1],['low','zero','high'])
plt.show()

# %%
t = np.arange(0.,5., 0.2)
plt.title('라인 플롯에서 여러개의 선 그리기')
plt.plot(t,t, 'r--', t, 0.5 * t**2, 'bs:', t, 0.2 * t**3, 'g^-')
plt.show()

# %%
plt.title('복수의 plot 명령을 한 그림에서 표현')
style1 = {'c' : 'b', 'lw':5, 'ls' : '--', 'marker' : 'o' , 'ms':15, 'mec':'g', 'mew':5, 'mfc': 'r'}
style2 = {'c' : 'k', 'lw':3, 'ls' : ':', 'marker' : 's' , 'ms':10, 'mec':'m', 'mew':5, 'mfc': 'c'}

plt.plot([1,4,9,16], **style1)
plt.plot([9,16,4,1], **style2)

plt.show()

# %% [raw]
# 범례(Legend)
# 여러개의 라인 플롯을 동시에 그리는 경우에는 각 선이 무슨 자료를 표시하는지를 보여주기 위해 legend 명령으로 범례를 추가할 수 있습니다.
# 범례의 위치는 자동으로 정해지지만 수동으로 설정하고 싶으면 loc 키워드 인수를 사용합니다.

# %%
X = np.linspace(-np.pi, np.pi, 256)
C,S = np.cos(X) , np.sin(X)
plt.title('legend를 표시한 플롯')
plt.plot(X,C, ls='--', label='cosine')
plt.plot(X,S, ls=':', label='sine')
plt.xticks([-np.pi, -np.pi/2, 0, np.pi/2, np.pi],
          [r'$-\pi$', r'$-\pi/2$',r'$0$', r'$+\pi/2$', r'$+\pi$'])
plt.yticks([-1,0,1],['low','zero','high'])

plt.legend(loc=2)
plt.show()

# %%
X = np.linspace(-np.pi, np.pi, 256)
C,S = np.cos(X) , np.sin(X)
plt.title('sin & cos')
plt.plot(X,C, ls='--', label='cosine')
plt.plot(X,S, ls=':', label='sine')
plt.xticks([-np.pi, -np.pi/2, 0, np.pi/2, np.pi],
          [r'$-\pi$', r'$-\pi/2$',r'$0$', r'$+\pi/2$', r'$+\pi$'])
plt.yticks([-1,0,1],['low','zero','high'])
plt.xlabel('time')
plt.ylabel('amplitude')
plt.legend(loc=2)
plt.show()

# %%
plt.title('섭씨 온도와 화씨 온도')
X = np.arange(32,101)
Y = (X-32) * 5/9
plt.xlabel('화씨 온도')
plt.ylabel('섭씨 온도')
# plt.plot(X,Y, ls='-.', color='r')
plt.plot(X,Y, 'r-.')
plt.show()

# %% [raw]
# Figure
#
# Matplotlib는 data를 Figure에 x-y 좌표의 그래프로 표시합니다. (3차원은 x-y-z, 극좌표는 세타-r 등). 각각의 Figure는 하나 이상의 Axes를 갖습니다.
#
# 가장 간단하게 Figure, Axes 객체를 만드는 방법은 pyplot.subplots()을 사용하는 것입니다. 그 후 Axes.plot()를 활용하여 Axes에 데이터를 그립니다.

# %%
fig , ax = plt.subplots()
ax.plot([1,2,3,4],[1,4,2,3]);

# %%
fig = plt.figure()
fig, ax = plt.subplots()
fig, axs = plt.subplots(2,2)

# %%
np.random.seed(0)
fl = plt.figure(figsize=(10,2)) # size는 inch
plt.title('figsize (10,2)')
plt.plot(np.random.randn(100))
plt.show()

# %%
# 현재 사용하고 있는 Figure 객체를 얻으려면(다른 변수에 할당할 수도 있습니다.) gcf()메서드를 사용합니다.
f1 = plt.figure(1)
plt.title('현재의 figure 객체')
plt.plot([1,2,3,4], 'ro:')

f2 = plt.gcf()
print(f1, id(f1))
print(f2, id(f2))
plt.show()
# Out:
# Figure(640x480) 140610007368464
# Figure(640x480) 140610007368464

# %% [raw]
# Figure 객체 안에 여러 개의 플롯을 그리드 형태로 보여야하는 경우도 있습니다.
# Figure 안에 있는 각각 플롯은 Axes라고 불리는 객체에 속합ㄴ다.
#
# Figure 안에 Axes를 생성하려면 원래 subplot()을 사용하여 명시적으로 Axes 객체를 얻어야 합니다. 그러나 plot()을 바로 사용해도 자동으로 Figure, Axes 객체를 생성해줍니다.

# %% [raw]
# subplot()은 그리드 형태의 Axes 객체들을 생성합니다. Figure가 행렬이고 Axes가 행렬의 원소라고 생각하면 됩니다.
#
# 예를 들어 위와 아래 두개의 플롯이 있는 경우 행이 2 이고 열이 1인 2X1 행렬입니다.
# subplot 명령은 세개의 인수를 가지는데 처음 두개의 원소가 전체 그리드 행렬의 모양을 지시하는 두 숫자이고 세번째 인수가 네개 중 어느것인지를 의미하는 숫자가 됩니다.

# %%
ax1 = plt.subplot(2,1,1) # 여기에서 윗부분에 그릴 플롯 명령 실행
ax2 = plt.subplot(2,1,2) # 여기에서 아랫부분에 그릴 플로 명령 실행
